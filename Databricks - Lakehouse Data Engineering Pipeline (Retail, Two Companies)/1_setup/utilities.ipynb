# %% [markdown]
# # Project Utilities
#
# Shared schema-name defaults used by the downstream notebooks. Keep lightweight project-wide constants here so setup, dimension, and fact notebooks stay aligned.

# %%
"""Shared schema defaults reused across the project notebooks."""

bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"
