-- %% [markdown]
-- ### Create a denormalized Gold view for dashboard-friendly querying.

-- %%
%python
# Load the catalog name from Spark config, or use the default project catalog.
catalog_name = spark.conf.get("training_0002_ecommerce.catalog_name", "training_0002_ecommerce")

# Join the Gold fact table to product and date dimensions to expose a flatter serving model.
# Run the Spark SQL statement needed for this setup or transformation step.
spark.sql(f"""
CREATE OR REPLACE VIEW {catalog_name}.gold.fact_transactions_denorm AS (
SELECT i.*,
c.year,
c.month_name,
c.day_name,
c.is_weekend,
c.quarter,
c.week,
p.sku,
p.category_code,
p.category_name,
p.brand_code,
p.brand_name,
p.color,
p.size,
p.rating_count,
extract(HOUR FROM transaction_ts) as hour_of_day
FROM {catalog_name}.gold.gld_fact_order_items i JOIN {catalog_name}.gold.gld_dim_date c ON i.date_id = c.date_id
JOIN {catalog_name}.gold.gld_dim_products p ON i.product_id = p.product_id
)
""")
